# %% [markdown]
# <a href="https://colab.research.google.com/github/Maarioon/Learning-Python/blob/main/Copy_of_18_10_22_practise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Marion")
print("o----")
print(" !!!!")
# i just wrote a dog code

print("*" * 10) # this is an expression, which evaluates an expression and brings it out
print("(\/)")

 #definition nof variables
price = 10
print(price)
price = 20
print(price)

#integer is a no without decimal points

rating = 2.9
print(rating)

# exercise
#we check in a patient named John Smith
#He's 20 years old and is a new patient

full_name = 'John Smith'
age = 20
is_new = True
print(full_name)
print(age)
print(is_new)

# I also practised my if and else statement

patient = input("what is the name of the new patient? ")
age = input("How old is he? ")
print(patient)
print(age)
new = True
old = False
if patient is new :
  print(new)
else:
    print(old)

#how to receive message from user: using Input function-- it is more or less ;like a call and response function.
#input('what is your name? ')
#using the variable name to call it.

name = input('what is your name? ')
print("Hi, " + name)

#exersice
#Ask two questions:  person's name and favorite colour
name = input('what is your name? ')
print('Hi, ' + name)
colour =input('what is your favourite color? ')
print("Marion likes Black, Purple and White")

birth_year = input('what is your birth year? ')
age = 2022 - (int(birth_year))
print(age)
print(type(age))

#exercise
#ask the user their weight(in pounds), convert it to kilograms and print on the terminal

weight = input('what is your weight? ')
print(int(weight))
print(float(weight))

weight_lbs = input('weight (lbs): ')
weight_kg = int(weight_lbs) * 0.45
print(weight_lbs)
print(weight_kg)

#string for multiple lines or multiple strings
# you can triple quote the beginning and end of the sentence, even extend it to the next line.
# multi line string

course = ''' Hi Marion,

Here is our another Hamadani class you are doing.

thank you,

Yourself. '''
print(course)

#to get the index or the number placement of a vale square brackets are used []

note = 'Python is quiet easy'
print(note[0])
# Out:
# Marion
# o----
#  !!!!
# **********
# (\/)
# 10
# 20
# 2.9
# John Smith
# 20
# True
# what is the name of the new patient? John Smith
# How old is he? 20
# John Smith
# 20
# False
# what is your name? Marion
# Hi, Marion
# what is your name? Arike
# Hi, Arike
# what is your favourite color? Black, Purple, White
# Marion likes Black, Purple and White
# what is your birth year? 777
# 1245
# <class 'int'>
# what is your weight? 80
# 80
# 80.0
# weight (lbs): 80
# 80
# 36.0
#  Hi Marion,
#
# Here is our another Hamadani class you are doing.
#
# thank you,
#
# Yourself.
# P
